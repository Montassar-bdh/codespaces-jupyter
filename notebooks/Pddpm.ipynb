# %%
# !mkdir -p data/raw/IXI/t2
# !mkdir -p data/preprocessed/IXI
# !mkdir -p data/compressed/IXI

# %%
# !rm -rf biomedic.doc.ic.ac.uk/

# %%
# %cd /content/data/compressed/IXI/
# !wget http://biomedic.doc.ic.ac.uk/brain-development/downloads/IXI/IXI-T2.tar
# Out:
# /content/data/compressed/IXI
# --2023-07-27 01:00:01--  http://biomedic.doc.ic.ac.uk/brain-development/downloads/IXI/IXI-T2.tar
# Resolving biomedic.doc.ic.ac.uk (biomedic.doc.ic.ac.uk)... 146.169.22.31
# Connecting to biomedic.doc.ic.ac.uk (biomedic.doc.ic.ac.uk)|146.169.22.31|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://biomedic.doc.ic.ac.uk/brain-development/downloads/IXI/IXI-T2.tar [following]
# --2023-07-27 01:00:03--  https://biomedic.doc.ic.ac.uk/brain-development/downloads/IXI/IXI-T2.tar
# Connecting to biomedic.doc.ic.ac.uk (biomedic.doc.ic.ac.uk)|146.169.22.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3853445120 (3.6G) [application/x-tar]
# Saving to: ‘IXI-T2.tar’
#
# IXI-T2.tar          100%[===================>]   3.59G  13.5MB/s    in 4m 42s
#
# 2023-07-27 01:04:46 (13.0 MB/s) - ‘IXI-T2.tar’ saved [3853445120/3853445120]

# %%
# %cd /content/
# !ls -lh /content/data/compressed/IXI
# Out:
# /content
# total 3.6G
# -rw-r--r-- 1 root root 3.6G Oct  7  2014 IXI-T2.tar

# %%
# !tar -xf /content/data/compressed/IXI/IXI-T2.tar -C /content/data/raw/IXI/t2

# %%
# %cd /content/
# !rm -rf HD-BET
# Out:
# /content

# %%
# !git clone https://github.com/MIC-DKFZ/HD-BET.git
# Out:
# Cloning into 'HD-BET'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 178 (delta 31), reused 27 (delta 27), pack-reused 140
# Receiving objects: 100% (178/178), 40.03 KiB | 450.00 KiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# !rm -rf /content/patched-Diffusion-Models-UAD

# %%
# %cd /content/
# !git clone https://github.com/FinnBehrendt/patched-Diffusion-Models-UAD.git
# Out:
# /content
# Cloning into 'patched-Diffusion-Models-UAD'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 193 (delta 38), reused 183 (delta 33), pack-reused 0
# Receiving objects: 100% (193/193), 39.56 MiB | 15.86 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (142/142), done.

# %%
# !python -V

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2023-07-27 01:05:11--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   179MB/s    in 0.5s
#
# 2023-07-27 01:05:12 (179 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
# %cd /content/HD-BET
# !pip install -e .
# Out:
# /content/HD-BET
# Obtaining file:///content/HD-BET
# ...
#      |████████████████████████████████| 619.9 MB 12 kB/s
# ...
#      |████████████████████████████████| 13.9 MB 49.8 MB/s
# ...
#      |████████████████████████████████| 52.7 MB 80 kB/s
# ...
#      |████████████████████████████████| 102.6 MB 3.7 kB/s
# ...
#      |████████████████████████████████| 177.1 MB 64 kB/s
# ...
#      |████████████████████████████████| 98 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 63.2 MB 4.6 kB/s
# ...
#      |████████████████████████████████| 849 kB 28.3 MB/s
# ...
#      |████████████████████████████████| 317.1 MB 23 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 173.2 MB 22 kB/s
# ...
#      |████████████████████████████████| 2.1 MB 66.6 MB/s
# ...
#      |████████████████████████████████| 557.1 MB 10 kB/s
# ...
#      |████████████████████████████████| 54.6 MB 262 kB/s
# ...
#      |████████████████████████████████| 168.4 MB 53 kB/s
# ...
#      |████████████████████████████████| 5.7 MB 47.1 MB/s
# ...

# %%
# %cd /content/
# !rm -rf sample_data
# Out:
# /content

# %%
# !pip install -r /content/patched-Diffusion-Models-UAD/requirements.txt
# Out:
# ...
#   Using cached accelerate-0.7.1-py3-none-any.whl (79 kB)
# ...
#   Using cached albumentations-1.1.0-py3-none-any.whl (102 kB)
# ...
#   Using cached ants-0.0.7.tar.gz (10 kB)
# ...
#      |████████████████████████████████| 326.3 MB 2.6 kB/s
# ...
#      |████████████████████████████████| 4.5 MB 69.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 4.5 MB 60.4 MB/s
# ...
#      |████████████████████████████████| 144 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 55.9 MB/s
# ...
#      |████████████████████████████████| 565 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 65.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 96.2 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 66.6 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 49.2 MB/s
# ...
#      |████████████████████████████████| 74 kB 4.0 MB/s
# ...

# %%
# %cd /content/
# !hd-bet

# %%
# %cd /content/patched-Diffusion-Models-UAD/preprocessing
# !bash prepare_IXI.sh /content/data/raw/IXI /content/data/preprocessed/IXI
# Out:
# /content/patched-Diffusion-Models-UAD/preprocessing
# Generate masks
#
# ########################
# If you are using hd-bet, please cite the following paper:
# Isensee F, Schell M, Tursunova I, Brugnara G, Bonekamp D, Neuberger U, Wick A, Schlemmer HP, Heiland S, Wick W,Bendszus M, Maier-Hein KH, Kickingereder P. Automated brain extraction of multi-sequence MRI using artificialneural networks. arXiv preprint arXiv:1901.11341, 2019.
# ########################
#
# ...
# File: /content/data/preprocessed/IXI/v1resampled/IXI/t2/IXI012-HH-1211_t2.nii.gz
# preprocessing...
# image shape after preprocessing:  (89, 153, 153)
# prediction (CNN id)...
# 0
# 1
# 2
# 3
# 4
# running postprocessing...
# exporting segmentation...
# File: /content/data/preprocessed/IXI/v1resampled/IXI/t2/IXI013-HH-1212_t2.nii.gz
# preprocessing...
# image shape after preprocessing:  (93, 153, 153)
# prediction (CNN id)...
# 0
# 1
# 2
# 3
# 4
# running postprocessing...
# exporting segmentation...
# ...

# %%
# !rm -rf /content/data/raw/IXI/t2/*

# %%
import shutil
